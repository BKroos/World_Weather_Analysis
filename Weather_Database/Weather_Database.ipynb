# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from config_1 import weather_api_key
from citipy import citipy

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
       
len(cities)
# Out:
# 753

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | sinop
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | gornopravdinsk
# Processing Record 12 of Set 1 | shingu
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | moron
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | verkh-usugli
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | tocopilla
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | flin flon
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | cortez
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | uhlirske janovice
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | istanbul
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | san andres
# Processing Record 38 of Set 1 | angoche
# Processing Record 39 of Set 1 | pergamino
# Processing Record 40 of Set 1 | mnogovershinnyy
# Processing Record 41 of Set 1 | sanmenxia
# Processing Record 42 of Set 1 | tevaitoa
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | darab
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | kupang
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | teknaf
# Processing Record 1 of Set 2 | mecayapan
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | juneau
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | shenjiamen
# Processing Record 8 of Set 2 | port-gentil
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | sakakah
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | prince rupert
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | kavaratti
# Processing Record 18 of Set 2 | christchurch
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | naron
# Processing Record 21 of Set 2 | inhambane
# Processing Record 22 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 2 | isangel
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | norton shores
# Processing Record 28 of Set 2 | gorgan
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | san ramon
# Processing Record 31 of Set 2 | nuuk
# Processing Record 32 of Set 2 | hilton head island
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | rio gallegos
# Processing Record 35 of Set 2 | mecca
# Processing Record 36 of Set 2 | coral springs
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | satipo
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | mangai
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | olkhovka
# Processing Record 43 of Set 2 | pacific grove
# Processing Record 44 of Set 2 | darhan
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | guatire
# Processing Record 47 of Set 2 | vila franca do campo
# Processing Record 48 of Set 2 | college
# Processing Record 49 of Set 2 | salinopolis
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | maridi
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | ivanteyevka
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | roebourne
# Processing Record 9 of Set 3 | akropong
# Processing Record 10 of Set 3 | toora-khem
# Processing Record 11 of Set 3 | kostomuksha
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | russell
# Processing Record 14 of Set 3 | bara
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | edgewater
# Processing Record 17 of Set 3 | orbetello
# Processing Record 18 of Set 3 | general roca
# Processing Record 19 of Set 3 | ceres
# Processing Record 20 of Set 3 | trelew
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | mukdahan
# Processing Record 23 of Set 3 | kenai
# Processing Record 24 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | lethem
# Processing Record 27 of Set 3 | palmer
# Processing Record 28 of Set 3 | bata
# Processing Record 29 of Set 3 | berbera
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | bushehr
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | bogatic
# Processing Record 34 of Set 3 | kachug
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | marsh harbour
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | puerto madero
# Processing Record 40 of Set 3 | bokoro
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | ekuvukeni
# Processing Record 43 of Set 3 | lorengau
# Processing Record 44 of Set 3 | aguada de pasajeros
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | mehamn
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | teguise
# Processing Record 50 of Set 3 | matinhos
# Processing Record 1 of Set 4 | gat
# Processing Record 2 of Set 4 | bozeman
# Processing Record 3 of Set 4 | tasiilaq
# Processing Record 4 of Set 4 | san juan de los morros
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | flinders
# Processing Record 7 of Set 4 | asau
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | megion
# Processing Record 10 of Set 4 | akita
# Processing Record 11 of Set 4 | bilibino
# Processing Record 12 of Set 4 | egvekinot
# Processing Record 13 of Set 4 | ormara
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | coos bay
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | zheleznodorozhnyy
# Processing Record 19 of Set 4 | saint johnsbury
# Processing Record 20 of Set 4 | auki
# Processing Record 21 of Set 4 | namatanai
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | kibungo
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | port macquarie
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | los llanos de aridane
# Processing Record 28 of Set 4 | sheffield
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | viedma
# Processing Record 32 of Set 4 | chapais
# Processing Record 33 of Set 4 | zhicheng
# Processing Record 34 of Set 4 | leshukonskoye
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | sibolga
# Processing Record 37 of Set 4 | dolores hidalgo
# Processing Record 38 of Set 4 | necochea
# Processing Record 39 of Set 4 | urulga
# City not found. Skipping...
# Processing Record 40 of Set 4 | puerto baquerizo moreno
# Processing Record 41 of Set 4 | karratha
# Processing Record 42 of Set 4 | alice springs
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | dingle
# Processing Record 45 of Set 4 | haines junction
# Processing Record 46 of Set 4 | hofn
# Processing Record 47 of Set 4 | chokurdakh
# Processing Record 48 of Set 4 | vestmannaeyjar
# Processing Record 49 of Set 4 | cape town
# Processing Record 50 of Set 4 | yaan
# Processing Record 1 of Set 5 | boddam
# Processing Record 2 of Set 5 | malko tarnovo
# Processing Record 3 of Set 5 | nchelenge
# Processing Record 4 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | coihaique
# Processing Record 7 of Set 5 | salisbury
# Processing Record 8 of Set 5 | sambava
# Processing Record 9 of Set 5 | cairns
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | kralendijk
# Processing Record 12 of Set 5 | buin
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | quimper
# Processing Record 15 of Set 5 | shirakawa
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | freeport
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | padang
# Processing Record 20 of Set 5 | coulihaut
# City not found. Skipping...
# Processing Record 21 of Set 5 | pangnirtung
# Processing Record 22 of Set 5 | ponta do sol
# Processing Record 23 of Set 5 | storforshei
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | porto novo
# Processing Record 26 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 5 | portland
# Processing Record 28 of Set 5 | dok kham tai
# Processing Record 29 of Set 5 | westport
# Processing Record 30 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | ukiah
# Processing Record 35 of Set 5 | wlodawa
# Processing Record 36 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 5 | yellandu
# Processing Record 38 of Set 5 | constantine
# Processing Record 39 of Set 5 | salym
# Processing Record 40 of Set 5 | farah
# Processing Record 41 of Set 5 | gigmoto
# Processing Record 42 of Set 5 | pundaguitan
# Processing Record 43 of Set 5 | grindavik
# Processing Record 44 of Set 5 | bima
# Processing Record 45 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 5 | atbasar
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | mountain home
# Processing Record 50 of Set 5 | henties bay
# Processing Record 1 of Set 6 | xai-xai
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | wewak
# Processing Record 4 of Set 6 | georgetown
# Processing Record 5 of Set 6 | belaya gora
# Processing Record 6 of Set 6 | santa rosalia
# Processing Record 7 of Set 6 | golden
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | campana
# Processing Record 10 of Set 6 | ptolemais
# Processing Record 11 of Set 6 | batagay-alyta
# Processing Record 12 of Set 6 | aksay
# Processing Record 13 of Set 6 | savinskiy
# Processing Record 14 of Set 6 | jibuti
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | santarem
# Processing Record 18 of Set 6 | kishtwar
# Processing Record 19 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 20 of Set 6 | calama
# Processing Record 21 of Set 6 | solnechnyy
# Processing Record 22 of Set 6 | moroni
# Processing Record 23 of Set 6 | isabela
# Processing Record 24 of Set 6 | port blair
# Processing Record 25 of Set 6 | berlevag
# Processing Record 26 of Set 6 | namestovo
# Processing Record 27 of Set 6 | le portel
# Processing Record 28 of Set 6 | shimoda
# Processing Record 29 of Set 6 | kamenka
# Processing Record 30 of Set 6 | nizwa
# Processing Record 31 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 6 | chamalieres
# Processing Record 33 of Set 6 | ternate
# Processing Record 34 of Set 6 | tateyama
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | imbituba
# Processing Record 37 of Set 6 | labytnangi
# Processing Record 38 of Set 6 | white center
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | the valley
# Processing Record 41 of Set 6 | lindi
# Processing Record 42 of Set 6 | shelburne
# Processing Record 43 of Set 6 | vila
# Processing Record 44 of Set 6 | palmares do sul
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | ibanda
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | sechura
# Processing Record 49 of Set 6 | dunedin
# Processing Record 50 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 7 | amahai
# Processing Record 2 of Set 7 | swan hill
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | cotonou
# Processing Record 5 of Set 7 | yarkovo
# Processing Record 6 of Set 7 | olds
# Processing Record 7 of Set 7 | kalmunai
# Processing Record 8 of Set 7 | alyangula
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | sonoita
# Processing Record 11 of Set 7 | mpulungu
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | pisco
# Processing Record 14 of Set 7 | chimoio
# Processing Record 15 of Set 7 | pitimbu
# Processing Record 16 of Set 7 | pontianak
# Processing Record 17 of Set 7 | sioux lookout
# Processing Record 18 of Set 7 | concarneau
# Processing Record 19 of Set 7 | svetlogorsk
# Processing Record 20 of Set 7 | narsaq
# Processing Record 21 of Set 7 | olafsvik
# Processing Record 22 of Set 7 | kjollefjord
# Processing Record 23 of Set 7 | praia da vitoria
# Processing Record 24 of Set 7 | mpongwe
# Processing Record 25 of Set 7 | wamba
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | yar-sale
# Processing Record 28 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 7 | tierranueva
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | yenagoa
# Processing Record 32 of Set 7 | moose factory
# Processing Record 33 of Set 7 | tazovskiy
# Processing Record 34 of Set 7 | gubkinskiy
# Processing Record 35 of Set 7 | avallon
# Processing Record 36 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 7 | melfi
# Processing Record 38 of Set 7 | andenes
# Processing Record 39 of Set 7 | konstantinovo
# Processing Record 40 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | mendeleyevo
# Processing Record 42 of Set 7 | hithadhoo
# Processing Record 43 of Set 7 | lingao
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | funtua
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | praya
# Processing Record 48 of Set 7 | skvyra
# Processing Record 49 of Set 7 | kota
# Processing Record 50 of Set 7 | te anau
# Processing Record 1 of Set 8 | changping
# Processing Record 2 of Set 8 | tiksi
# Processing Record 3 of Set 8 | camacha
# Processing Record 4 of Set 8 | shelopugino
# Processing Record 5 of Set 8 | itambe
# Processing Record 6 of Set 8 | porto belo
# Processing Record 7 of Set 8 | fiumicino
# Processing Record 8 of Set 8 | sao miguel dos campos
# Processing Record 9 of Set 8 | ariquemes
# Processing Record 10 of Set 8 | lagoa
# Processing Record 11 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | bud
# Processing Record 14 of Set 8 | atar
# Processing Record 15 of Set 8 | batagay
# Processing Record 16 of Set 8 | narasannapeta
# Processing Record 17 of Set 8 | kattivakkam
# Processing Record 18 of Set 8 | balaka
# Processing Record 19 of Set 8 | banjar
# Processing Record 20 of Set 8 | port hedland
# Processing Record 21 of Set 8 | chara
# Processing Record 22 of Set 8 | kabare
# Processing Record 23 of Set 8 | srivardhan
# Processing Record 24 of Set 8 | arezzo
# Processing Record 25 of Set 8 | liberal
# Processing Record 26 of Set 8 | islamkot
# Processing Record 27 of Set 8 | kodar
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | colesberg
# Processing Record 30 of Set 8 | mareeba
# Processing Record 31 of Set 8 | santo antonio do ica
# Processing Record 32 of Set 8 | miles city
# Processing Record 33 of Set 8 | botwood
# Processing Record 34 of Set 8 | kristinehamn
# Processing Record 35 of Set 8 | vilcun
# Processing Record 36 of Set 8 | port hawkesbury
# Processing Record 37 of Set 8 | gogrial
# Processing Record 38 of Set 8 | abu kamal
# Processing Record 39 of Set 8 | turbat
# Processing Record 40 of Set 8 | nemuro
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | kundgol
# Processing Record 43 of Set 8 | bilma
# Processing Record 44 of Set 8 | tongzi
# Processing Record 45 of Set 8 | klaksvik
# Processing Record 46 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | ahuimanu
# Processing Record 49 of Set 8 | santa marta
# Processing Record 50 of Set 8 | bull savanna
# Processing Record 1 of Set 9 | domingos martins
# Processing Record 2 of Set 9 | riberalta
# Processing Record 3 of Set 9 | ganzhou
# Processing Record 4 of Set 9 | popondetta
# Processing Record 5 of Set 9 | surt
# Processing Record 6 of Set 9 | atlantic beach
# Processing Record 7 of Set 9 | muros
# Processing Record 8 of Set 9 | nouna
# Processing Record 9 of Set 9 | storsteinnes
# Processing Record 10 of Set 9 | baruun-urt
# Processing Record 11 of Set 9 | machali
# Processing Record 12 of Set 9 | garissa
# Processing Record 13 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 14 of Set 9 | rongcheng
# Processing Record 15 of Set 9 | bisira
# Processing Record 16 of Set 9 | paamiut
# Processing Record 17 of Set 9 | hamina
# Processing Record 18 of Set 9 | curaca
# Processing Record 19 of Set 9 | phalombe
# Processing Record 20 of Set 9 | edea
# Processing Record 21 of Set 9 | manjeshwar
# Processing Record 22 of Set 9 | sheboygan
# Processing Record 23 of Set 9 | rawson
# Processing Record 24 of Set 9 | moletai
# Processing Record 25 of Set 9 | santa fe
# Processing Record 26 of Set 9 | nigran
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | waycross
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | leeston
# Processing Record 31 of Set 9 | garm
# City not found. Skipping...
# Processing Record 32 of Set 9 | vanavara
# Processing Record 33 of Set 9 | natal
# Processing Record 34 of Set 9 | cockburn town
# Processing Record 35 of Set 9 | mora
# Processing Record 36 of Set 9 | kashary
# Processing Record 37 of Set 9 | korla
# Processing Record 38 of Set 9 | ilhabela
# Processing Record 39 of Set 9 | bodden town
# Processing Record 40 of Set 9 | hutchinson
# Processing Record 41 of Set 9 | kaeo
# Processing Record 42 of Set 9 | lubango
# Processing Record 43 of Set 9 | yaring
# Processing Record 44 of Set 9 | nabire
# Processing Record 45 of Set 9 | xinmin
# Processing Record 46 of Set 9 | praia
# Processing Record 47 of Set 9 | fomboni
# Processing Record 48 of Set 9 | northam
# Processing Record 49 of Set 9 | toamasina
# Processing Record 50 of Set 9 | adrar
# Processing Record 1 of Set 10 | khorramabad
# Processing Record 2 of Set 10 | bad hersfeld
# Processing Record 3 of Set 10 | aguimes
# Processing Record 4 of Set 10 | madimba
# Processing Record 5 of Set 10 | riyadh
# Processing Record 6 of Set 10 | bathsheba
# Processing Record 7 of Set 10 | ravar
# Processing Record 8 of Set 10 | bacolod
# Processing Record 9 of Set 10 | deputatskiy
# Processing Record 10 of Set 10 | puerto suarez
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | desert hot springs
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | kulhudhuffushi
# Processing Record 15 of Set 10 | okhotsk
# Processing Record 16 of Set 10 | honiara
# Processing Record 17 of Set 10 | stanislav
# Processing Record 18 of Set 10 | pathein
# Processing Record 19 of Set 10 | fort nelson
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | bururi
# Processing Record 22 of Set 10 | soyo
# Processing Record 23 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 10 | ust-tsilma
# Processing Record 25 of Set 10 | kutum
# Processing Record 26 of Set 10 | novosergiyevka
# Processing Record 27 of Set 10 | bardejov
# Processing Record 28 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 10 | birobidzhan
# Processing Record 30 of Set 10 | beringovskiy
# Processing Record 31 of Set 10 | vaitape
# Processing Record 32 of Set 10 | port augusta
# Processing Record 33 of Set 10 | kanniyakumari
# Processing Record 34 of Set 10 | bignona
# Processing Record 35 of Set 10 | san cristobal
# Processing Record 36 of Set 10 | mansfield
# Processing Record 37 of Set 10 | road town
# Processing Record 38 of Set 10 | dawei
# Processing Record 39 of Set 10 | talikota
# Processing Record 40 of Set 10 | ostrovskoye
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | nishihara
# Processing Record 43 of Set 10 | murud
# Processing Record 44 of Set 10 | esna
# Processing Record 45 of Set 10 | kangaatsiaq
# Processing Record 46 of Set 10 | zhoucheng
# Processing Record 47 of Set 10 | sisimiut
# Processing Record 48 of Set 10 | yanam
# Processing Record 49 of Set 10 | coquimbo
# Processing Record 50 of Set 10 | dajabon
# Processing Record 1 of Set 11 | victor harbor
# Processing Record 2 of Set 11 | provideniya
# Processing Record 3 of Set 11 | impfondo
# Processing Record 4 of Set 11 | kollo
# Processing Record 5 of Set 11 | vrede
# Processing Record 6 of Set 11 | mayo
# Processing Record 7 of Set 11 | sinnai
# Processing Record 8 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 9 of Set 11 | fortuna
# Processing Record 10 of Set 11 | cootamundra
# Processing Record 11 of Set 11 | roald
# Processing Record 12 of Set 11 | sorong
# Processing Record 13 of Set 11 | cayenne
# Processing Record 14 of Set 11 | olinda
# Processing Record 15 of Set 11 | codrington
# Processing Record 16 of Set 11 | serenje
# Processing Record 17 of Set 11 | plenita
# Processing Record 18 of Set 11 | naze
# Processing Record 19 of Set 11 | tessalit
# Processing Record 20 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | mayya
# Processing Record 22 of Set 11 | casablanca
# Processing Record 23 of Set 11 | oranjemund
# Processing Record 24 of Set 11 | weyburn
# Processing Record 25 of Set 11 | quesnel
# Processing Record 26 of Set 11 | hualmay
# Processing Record 27 of Set 11 | sampit
# Processing Record 28 of Set 11 | biak
# Processing Record 29 of Set 11 | sibuco
# Processing Record 30 of Set 11 | bubaque
# Processing Record 31 of Set 11 | saint-georges
# Processing Record 32 of Set 11 | monopoli
# Processing Record 33 of Set 11 | oksfjord
# Processing Record 34 of Set 11 | hyeres
# Processing Record 35 of Set 11 | micheweni
# Processing Record 36 of Set 11 | elat
# Processing Record 37 of Set 11 | tha chang
# Processing Record 38 of Set 11 | goroka
# Processing Record 39 of Set 11 | bogande
# Processing Record 40 of Set 11 | aksarka
# Processing Record 41 of Set 11 | yinchuan
# Processing Record 42 of Set 11 | antsohihy
# Processing Record 43 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 11 | waipawa
# Processing Record 45 of Set 11 | pochutla
# Processing Record 46 of Set 11 | medowie
# Processing Record 47 of Set 11 | oliveira
# Processing Record 48 of Set 11 | sembe
# Processing Record 49 of Set 11 | juegang
# Processing Record 50 of Set 11 | van
# Processing Record 1 of Set 12 | payo
# Processing Record 2 of Set 12 | gondar
# Processing Record 3 of Set 12 | golubitskaya
# Processing Record 4 of Set 12 | gorontalo
# Processing Record 5 of Set 12 | kysyl-syr
# Processing Record 6 of Set 12 | luderitz
# Processing Record 7 of Set 12 | poya
# Processing Record 8 of Set 12 | zvishavane
# Processing Record 9 of Set 12 | kawanoe
# Processing Record 10 of Set 12 | palu
# Processing Record 11 of Set 12 | el cope
# Processing Record 12 of Set 12 | kemalpasa
# Processing Record 13 of Set 12 | noumea
# Processing Record 14 of Set 12 | otane
# Processing Record 15 of Set 12 | vieux-habitants
# Processing Record 16 of Set 12 | manbij
# Processing Record 17 of Set 12 | oros
# Processing Record 18 of Set 12 | inyonga
# Processing Record 19 of Set 12 | acajutla
# Processing Record 20 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | marmaron
# City not found. Skipping...
# Processing Record 23 of Set 12 | zunheboto
# Processing Record 24 of Set 12 | ketchikan
# Processing Record 25 of Set 12 | tres lagoas
# Processing Record 26 of Set 12 | serra negra
# Processing Record 27 of Set 12 | vanimo
# Processing Record 28 of Set 12 | siavonga
# Processing Record 29 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 30 of Set 12 | presque isle
# Processing Record 31 of Set 12 | vao
# Processing Record 32 of Set 12 | betioky
# Processing Record 33 of Set 12 | mocuba
# Processing Record 34 of Set 12 | charters towers
# Processing Record 35 of Set 12 | kirkcudbright
# Processing Record 36 of Set 12 | mezen
# Processing Record 37 of Set 12 | pokhara
# Processing Record 38 of Set 12 | acarau
# Processing Record 39 of Set 12 | campbeltown
# Processing Record 40 of Set 12 | walvis bay
# Processing Record 41 of Set 12 | qaqortoq
# Processing Record 42 of Set 12 | great yarmouth
# Processing Record 43 of Set 12 | barcelos
# Processing Record 44 of Set 12 | mana
# Processing Record 45 of Set 12 | nova granada
# Processing Record 46 of Set 12 | bahia blanca
# Processing Record 47 of Set 12 | salalah
# Processing Record 48 of Set 12 | ilebo
# Processing Record 49 of Set 12 | cobija
# Processing Record 50 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 13 | roma
# Processing Record 2 of Set 13 | bissau
# Processing Record 3 of Set 13 | kununurra
# Processing Record 4 of Set 13 | evensk
# Processing Record 5 of Set 13 | shushtar
# Processing Record 6 of Set 13 | shahr-e babak
# Processing Record 7 of Set 13 | biltine
# Processing Record 8 of Set 13 | san felipe
# Processing Record 9 of Set 13 | kirakira
# Processing Record 10 of Set 13 | alibag
# Processing Record 11 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | nantucket
# Processing Record 13 of Set 13 | villa maria
# Processing Record 14 of Set 13 | rapid valley
# Processing Record 15 of Set 13 | monrovia
# Processing Record 16 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 13 | kismayo
# Processing Record 18 of Set 13 | dmitriyevka
# Processing Record 19 of Set 13 | port lincoln
# Processing Record 20 of Set 13 | manokwari
# Processing Record 21 of Set 13 | mount gambier
# Processing Record 22 of Set 13 | jurm
# Processing Record 23 of Set 13 | banes
# Processing Record 24 of Set 13 | umm lajj
# Processing Record 25 of Set 13 | quang ngai
# Processing Record 26 of Set 13 | lakes entrance
# Processing Record 27 of Set 13 | huambo
# Processing Record 28 of Set 13 | chengde
# Processing Record 29 of Set 13 | bay saint louis
# Processing Record 30 of Set 13 | wagar
# Processing Record 31 of Set 13 | nanortalik
# Processing Record 32 of Set 13 | voyvozh
# Processing Record 33 of Set 13 | kiama
# Processing Record 34 of Set 13 | laguna
# Processing Record 35 of Set 13 | udachnyy
# Processing Record 36 of Set 13 | pogar
# Processing Record 37 of Set 13 | mbacke
# City not found. Skipping...
# Processing Record 38 of Set 13 | chernyshevskiy
# Processing Record 39 of Set 13 | aitape
# Processing Record 40 of Set 13 | letka
# Processing Record 41 of Set 13 | ishigaki
# Processing Record 42 of Set 13 | merauke
# Processing Record 43 of Set 13 | mbekenyera
# Processing Record 44 of Set 13 | tautira
# Processing Record 45 of Set 13 | suslonger
# Processing Record 46 of Set 13 | mgandu
# Processing Record 47 of Set 13 | sibu
# Processing Record 48 of Set 13 | rovaniemi
# Processing Record 49 of Set 13 | sterlibashevo
# Processing Record 50 of Set 13 | magadan
# Processing Record 1 of Set 14 | shaoguan
# Processing Record 2 of Set 14 | huilong
# Processing Record 3 of Set 14 | tabuk
# Processing Record 4 of Set 14 | ibotirama
# Processing Record 5 of Set 14 | aljezur
# Processing Record 6 of Set 14 | havelock
# Processing Record 7 of Set 14 | caravelas
# Processing Record 8 of Set 14 | katangli
# Processing Record 9 of Set 14 | kebemer
# City not found. Skipping...
# Processing Record 10 of Set 14 | aksu
# Processing Record 11 of Set 14 | kaabong
# Processing Record 12 of Set 14 | baykit
# Processing Record 13 of Set 14 | ossora
# Processing Record 14 of Set 14 | petrovsk
# Processing Record 15 of Set 14 | omboue
# Processing Record 16 of Set 14 | canakkale
# Processing Record 17 of Set 14 | poum
# Processing Record 18 of Set 14 | pictou
# Processing Record 19 of Set 14 | alekseyevsk
# Processing Record 20 of Set 14 | marrakesh
# Processing Record 21 of Set 14 | paracatu
# Processing Record 22 of Set 14 | kurmanayevka
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | mackenzie
# Processing Record 25 of Set 14 | rocha
# Processing Record 26 of Set 14 | yuancheng
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | banamba
# Processing Record 29 of Set 14 | slobozia
# Processing Record 30 of Set 14 | katobu
# Processing Record 31 of Set 14 | turukhansk
# Processing Record 32 of Set 14 | visnes
# Processing Record 33 of Set 14 | bonavista
# Processing Record 34 of Set 14 | palekh
# Processing Record 35 of Set 14 | villa bruzual
# Processing Record 36 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 14 | iranshahr
# Processing Record 38 of Set 14 | davila
# Processing Record 39 of Set 14 | vardo
# Processing Record 40 of Set 14 | sayyan
# Processing Record 41 of Set 14 | dryden
# Processing Record 42 of Set 14 | san lorenzo
# Processing Record 43 of Set 14 | rawlins
# Processing Record 44 of Set 14 | topeka
# Processing Record 45 of Set 14 | hobyo
# Processing Record 46 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 14 | buritama
# Processing Record 48 of Set 14 | ulladulla
# Processing Record 49 of Set 14 | ixtapa
# Processing Record 50 of Set 14 | maraba
# Processing Record 1 of Set 15 | tulun
# Processing Record 2 of Set 15 | ginir
# Processing Record 3 of Set 15 | deep river
# Processing Record 4 of Set 15 | batouri
# Processing Record 5 of Set 15 | lac du bonnet
# Processing Record 6 of Set 15 | sarakhs
# Processing Record 7 of Set 15 | ahipara
# Processing Record 8 of Set 15 | tuy hoa
# Processing Record 9 of Set 15 | khomeyn
# Processing Record 10 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 15 | eyl
# Processing Record 12 of Set 15 | lompoc
# Processing Record 13 of Set 15 | coaldale
# Processing Record 14 of Set 15 | suntar
# Processing Record 15 of Set 15 | kyren
# Processing Record 16 of Set 15 | aloleng
# Processing Record 17 of Set 15 | boa vista
# Processing Record 18 of Set 15 | laela
# Processing Record 19 of Set 15 | chumikan
# Processing Record 20 of Set 15 | ovsyanka
# Processing Record 21 of Set 15 | byron bay
# Processing Record 22 of Set 15 | sur
# Processing Record 23 of Set 15 | tocache
# Processing Record 24 of Set 15 | kashi
# Processing Record 25 of Set 15 | podosinovets
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | ovre ardal
# Processing Record 28 of Set 15 | tonj
# Processing Record 29 of Set 15 | ewa beach
# Processing Record 30 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 15 | san quintin
# Processing Record 32 of Set 15 | vysotsk
# Processing Record 33 of Set 15 | murwara
# Processing Record 34 of Set 15 | san martin
# Processing Record 35 of Set 15 | montes altos
# Processing Record 36 of Set 15 | sokoni
# Processing Record 37 of Set 15 | peniche
# Processing Record 38 of Set 15 | lida
# Processing Record 39 of Set 15 | zeya
# Processing Record 40 of Set 15 | maniitsoq
# Processing Record 41 of Set 15 | kalabo
# Processing Record 42 of Set 15 | kiunga
# Processing Record 43 of Set 15 | tongren
# Processing Record 44 of Set 15 | buala
# Processing Record 45 of Set 15 | sorrento
# Processing Record 46 of Set 15 | nouadhibou
# Processing Record 47 of Set 15 | esmeraldas
# Processing Record 48 of Set 15 | tezu
# Processing Record 49 of Set 15 | maragogi
# Processing Record 50 of Set 15 | cusset
# Processing Record 1 of Set 16 | hervey bay
# Processing Record 2 of Set 16 | acapulco
# Processing Record 3 of Set 16 | torbat-e jam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City                   704
# Lat                    704
# Lng                    704
# Max Temp               704
# Current Description    704
# Humidity               704
# Cloudiness             704
# Wind Speed             704
# Country                704
# dtype: int64

# %%
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0  Punta Arenas -53.1500  -70.9167     42.91          light rain        70
# 1          Nome  64.5011 -165.4064     28.47     overcast clouds        74
# 2     Busselton -33.6500  115.3333     48.09    scattered clouds        81
# 3      Souillac -20.5167   57.5167     73.78       broken clouds        73
# 4        Avarua -21.2078 -159.7750     75.25     overcast clouds        83
#
#    Cloudiness  Wind Speed Country
# 0          75       16.11      CL
# 1          90        9.22      US
# 2          38       10.89      AU
# 3          75       11.50      MU
# 4          92        3.44      CK

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     42.91        70          75
# 1             Nome      US  64.5011 -165.4064     28.47        74          90
# 2        Busselton      AU -33.6500  115.3333     48.09        81          38
# 3         Souillac      MU -20.5167   57.5167     73.78        73          75
# 4           Avarua      CK -21.2078 -159.7750     75.25        83          92
# 5             Hami      CN  42.8000   93.4500     64.74        36          77
# 6            Sinop      TR  41.7711   34.8709     52.23        87          61
# 7  Bambous Virieux      MU -20.3428   57.7575     73.65        73          75
# 8   Cabo San Lucas      MX  22.8909 -109.9124     80.91        73           1
# 9            Vaini      TO -21.2000 -175.2000     71.76       100          40
#
#    Wind Speed Current Description
# 0       16.11          light rain
# 1        9.22     overcast clouds
# 2       10.89    scattered clouds
# 3       11.50       broken clouds
# 4        3.44     overcast clouds
# 5       23.13       broken clouds
# 6        3.44       broken clouds
# 7       11.50       broken clouds
# 8        0.00           clear sky
# 9        8.05    scattered clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
